# %%
import requests
import csv
import time
import logging

# %%
# Configure logging
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[logging.StreamHandler()]
)

# %%
import http.client as http_client
http_client.HTTPConnection.debuglevel = 1

# %%
# Define a function to capture HTTP client debug output
def http_client_debug(*args):
    logging.debug(' '.join(args))

# Patch the print function in the http.client module to use the custom function
http_client.print = http_client_debug

# %%
import requests
import csv
import time
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Define the API endpoint and parameters
url = 'https://services.nvd.nist.gov/rest/json/cves/2.0'
headers = {'apiKey': 'd0f53b52-e8ce-43c6-8e8d-20a6183c9a56'}
batch_size = 100  # Number of records per request
total_records = 2000  # Total number of records desired

# Initialize a list to hold all CVE items
all_cves = []

# Calculate the number of batches needed
num_batches = total_records // batch_size

# Loop to fetch multiple pages
for batch in range(num_batches):
    start_index = batch * batch_size
    params = {'startIndex': start_index, 'resultsPerPage': batch_size}
    logging.info(f"Fetching data with startIndex={start_index}")
    
    # Make the API request
    response = requests.get(url, headers=headers, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        logging.info(f"Successfully retrieved data for startIndex={start_index}")
        # Parse the JSON content
        data = response.json()
        
        # Extract the list of CVE items
        cve_items = data.get('vulnerabilities', [])
        
        # Add the current batch of CVEs to the list
        all_cves.extend(cve_items)
        
        # Respect NVD API rate limiting
        logging.info("Sleeping for 6 seconds to respect rate limiting.")
        time.sleep(6)  # NVD recommends sleeping for 6 seconds between requests
    else:
        logging.error(f"Failed to retrieve data: {response.status_code}")
        break

# Specify the CSV filename
csv_filename = 'nvd_cves.csv'

# Define the CSV headers
csv_headers = [
    'cve_id',
    'description',
    'published_date',
    'last_modified_date',
    'base_score',
    'base_severity'
]

# Open the CSV file in write mode and save the data
with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_headers)
    writer.writeheader()
    
    for cve in all_cves:
        cve_data = cve.get('cve', {})
        cve_id = cve_data.get('id', 'N/A')
        descriptions = cve_data.get('descriptions', [])
        description = next((desc['value'] for desc in descriptions if desc['lang'] == 'en'), 'N/A')
        published_date = cve_data.get('published', 'N/A')
        last_modified_date = cve_data.get('lastModified', 'N/A')
        
        # Extract CVSS metrics if available
        metrics = cve_data.get('metrics', {})
        cvss_metrics = metrics.get('cvssMetricV2', [])
        if cvss_metrics:
            base_score = cvss_metrics[0].get('cvssData', {}).get('baseScore', 'N/A')
            base_severity = cvss_metrics[0].get('baseSeverity', 'N/A')
        else:
            base_score = 'N/A'
            base_severity = 'N/A'
        
        # Write the row to the CSV file
        writer.writerow({
            'cve_id': cve_id,
            'description': description,
            'published_date': published_date,
            'last_modified_date': last_modified_date,
            'base_score': base_score,
            'base_severity': base_severity
        })

logging.info(f"Data successfully saved to {csv_filename}")
# Out:
# 2025-01-13 17:28:42,749 - INFO - Fetching data with startIndex=0
# 2025-01-13 17:28:42,753 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:28:43,474 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=0&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:28:43,988 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:28:43,989 - DEBUG - header: content-type: application/json
# 2025-01-13 17:28:43,990 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:28:43,990 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:28:43,990 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:28:43,990 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:28:43,991 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:28:43,991 - DEBUG - header: date: Mon, 13 Jan 2025 11:58:42 GMT
# 2025-01-13 17:28:43,991 - DEBUG - header: content-length: 208508
# 2025-01-13 17:28:43,992 - DEBUG - header: apikey: Yes
# 2025-01-13 17:28:43,992 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:28:43,992 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=0&resultsPerPage=100 HTTP/1.1" 200 208508
# 2025-01-13 17:28:44,552 - INFO - Successfully retrieved data for startIndex=0
# 2025-01-13 17:28:44,559 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:28:50,565 - INFO - Fetching data with startIndex=100
# 2025-01-13 17:28:50,569 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:28:51,270 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=100&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:28:57,792 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:28:57,793 - DEBUG - header: content-type: application/json
# 2025-01-13 17:28:57,793 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:28:57,793 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:28:57,794 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:28:57,794 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:28:57,794 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:28:57,795 - DEBUG - header: date: Mon, 13 Jan 2025 11:58:57 GMT
# 2025-01-13 17:28:57,795 - DEBUG - header: content-length: 223041
# 2025-01-13 17:28:57,795 - DEBUG - header: apikey: Yes
# 2025-01-13 17:28:57,795 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:28:57,796 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=100&resultsPerPage=100 HTTP/1.1" 200 223041
# 2025-01-13 17:28:58,482 - INFO - Successfully retrieved data for startIndex=100
# 2025-01-13 17:28:58,486 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:29:04,489 - INFO - Fetching data with startIndex=200
# 2025-01-13 17:29:04,492 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:29:05,205 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=200&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:29:05,718 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:29:05,720 - DEBUG - header: content-type: application/json
# 2025-01-13 17:29:05,720 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:29:05,720 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:29:05,720 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:29:05,721 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:29:05,721 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:29:05,721 - DEBUG - header: date: Mon, 13 Jan 2025 11:59:05 GMT
# 2025-01-13 17:29:05,721 - DEBUG - header: content-length: 225222
# 2025-01-13 17:29:05,722 - DEBUG - header: apikey: Yes
# 2025-01-13 17:29:05,722 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:29:05,722 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=200&resultsPerPage=100 HTTP/1.1" 200 225222
# 2025-01-13 17:29:06,437 - INFO - Successfully retrieved data for startIndex=200
# 2025-01-13 17:29:06,443 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:29:12,449 - INFO - Fetching data with startIndex=300
# 2025-01-13 17:29:12,453 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:29:13,167 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=300&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:29:13,668 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:29:13,669 - DEBUG - header: content-type: application/json
# 2025-01-13 17:29:13,670 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:29:13,670 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:29:13,670 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:29:13,670 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:29:13,671 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:29:13,671 - DEBUG - header: date: Mon, 13 Jan 2025 11:59:13 GMT
# 2025-01-13 17:29:13,671 - DEBUG - header: content-length: 191503
# 2025-01-13 17:29:13,671 - DEBUG - header: apikey: Yes
# 2025-01-13 17:29:13,672 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:29:13,672 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=300&resultsPerPage=100 HTTP/1.1" 200 191503
# 2025-01-13 17:29:14,210 - INFO - Successfully retrieved data for startIndex=300
# 2025-01-13 17:29:14,213 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:29:20,219 - INFO - Fetching data with startIndex=400
# 2025-01-13 17:29:20,223 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:29:20,924 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=400&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:29:21,445 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:29:21,447 - DEBUG - header: content-type: application/json
# 2025-01-13 17:29:21,447 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:29:21,448 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:29:21,448 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:29:21,448 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:29:21,448 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:29:21,449 - DEBUG - header: date: Mon, 13 Jan 2025 11:59:20 GMT
# 2025-01-13 17:29:21,449 - DEBUG - header: content-length: 233541
# 2025-01-13 17:29:21,449 - DEBUG - header: apikey: Yes
# 2025-01-13 17:29:21,450 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:29:21,450 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=400&resultsPerPage=100 HTTP/1.1" 200 233541
# 2025-01-13 17:29:22,156 - INFO - Successfully retrieved data for startIndex=400
# 2025-01-13 17:29:22,160 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:29:28,167 - INFO - Fetching data with startIndex=500
# 2025-01-13 17:29:28,170 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:29:28,906 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=500&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:29:29,431 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:29:29,433 - DEBUG - header: content-type: application/json
# 2025-01-13 17:29:29,433 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:29:29,433 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:29:29,434 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:29:29,434 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:29:29,434 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:29:29,435 - DEBUG - header: date: Mon, 13 Jan 2025 11:59:28 GMT
# 2025-01-13 17:29:29,435 - DEBUG - header: content-length: 200947
# 2025-01-13 17:29:29,435 - DEBUG - header: apikey: Yes
# 2025-01-13 17:29:29,436 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:29:29,436 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=500&resultsPerPage=100 HTTP/1.1" 200 200947
# 2025-01-13 17:29:29,999 - INFO - Successfully retrieved data for startIndex=500
# 2025-01-13 17:29:30,004 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:29:36,011 - INFO - Fetching data with startIndex=600
# 2025-01-13 17:29:36,014 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:29:36,731 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=600&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:29:43,183 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:29:43,185 - DEBUG - header: content-type: application/json
# 2025-01-13 17:29:43,185 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:29:43,186 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:29:43,186 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:29:43,186 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:29:43,187 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:29:43,187 - DEBUG - header: date: Mon, 13 Jan 2025 11:59:41 GMT
# 2025-01-13 17:29:43,187 - DEBUG - header: content-length: 175649
# 2025-01-13 17:29:43,187 - DEBUG - header: apikey: Yes
# 2025-01-13 17:29:43,187 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:29:43,188 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=600&resultsPerPage=100 HTTP/1.1" 200 175649
# 2025-01-13 17:29:43,716 - INFO - Successfully retrieved data for startIndex=600
# 2025-01-13 17:29:43,719 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:29:49,724 - INFO - Fetching data with startIndex=700
# 2025-01-13 17:29:49,727 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:29:50,408 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=700&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:29:56,446 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:29:56,447 - DEBUG - header: content-type: application/json
# 2025-01-13 17:29:56,448 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:29:56,448 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:29:56,448 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:29:56,449 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:29:56,449 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:29:56,449 - DEBUG - header: date: Mon, 13 Jan 2025 11:59:56 GMT
# 2025-01-13 17:29:56,450 - DEBUG - header: content-length: 136543
# 2025-01-13 17:29:56,450 - DEBUG - header: apikey: Yes
# 2025-01-13 17:29:56,450 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:29:56,451 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=700&resultsPerPage=100 HTTP/1.1" 200 136543
# 2025-01-13 17:29:56,928 - INFO - Successfully retrieved data for startIndex=700
# 2025-01-13 17:29:56,931 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:30:02,936 - INFO - Fetching data with startIndex=800
# 2025-01-13 17:30:02,939 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:30:03,624 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=800&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:30:14,201 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:30:14,202 - DEBUG - header: content-type: application/json
# 2025-01-13 17:30:14,203 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:30:14,203 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:30:14,203 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:30:14,203 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:30:14,204 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:30:14,204 - DEBUG - header: date: Mon, 13 Jan 2025 12:00:13 GMT
# 2025-01-13 17:30:14,204 - DEBUG - header: content-length: 176118
# 2025-01-13 17:30:14,205 - DEBUG - header: apikey: Yes
# 2025-01-13 17:30:14,205 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:30:14,205 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=800&resultsPerPage=100 HTTP/1.1" 200 176118
# 2025-01-13 17:30:14,714 - INFO - Successfully retrieved data for startIndex=800
# 2025-01-13 17:30:14,717 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:30:20,724 - INFO - Fetching data with startIndex=900
# 2025-01-13 17:30:20,727 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:30:21,458 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=900&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:30:34,815 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:30:34,817 - DEBUG - header: content-type: application/json
# 2025-01-13 17:30:34,817 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:30:34,818 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:30:34,818 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:30:34,818 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:30:34,818 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:30:34,819 - DEBUG - header: date: Mon, 13 Jan 2025 12:00:34 GMT
# 2025-01-13 17:30:34,819 - DEBUG - header: content-length: 174859
# 2025-01-13 17:30:34,819 - DEBUG - header: apikey: Yes
# 2025-01-13 17:30:34,820 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:30:34,820 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=900&resultsPerPage=100 HTTP/1.1" 200 174859
# 2025-01-13 17:30:35,359 - INFO - Successfully retrieved data for startIndex=900
# 2025-01-13 17:30:35,365 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:30:41,371 - INFO - Fetching data with startIndex=1000
# 2025-01-13 17:30:41,375 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:30:42,087 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=1000&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:30:43,104 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:30:43,106 - DEBUG - header: content-type: application/json
# 2025-01-13 17:30:43,106 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:30:43,107 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:30:43,107 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:30:43,107 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:30:43,108 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:30:43,108 - DEBUG - header: date: Mon, 13 Jan 2025 12:00:42 GMT
# 2025-01-13 17:30:43,108 - DEBUG - header: content-length: 193472
# 2025-01-13 17:30:43,108 - DEBUG - header: apikey: Yes
# 2025-01-13 17:30:43,109 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:30:43,110 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=1000&resultsPerPage=100 HTTP/1.1" 200 193472
# 2025-01-13 17:30:43,647 - INFO - Successfully retrieved data for startIndex=1000
# 2025-01-13 17:30:43,650 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:30:49,657 - INFO - Fetching data with startIndex=1100
# 2025-01-13 17:30:49,660 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:30:50,392 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=1100&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:30:51,144 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:30:51,146 - DEBUG - header: content-type: application/json
# 2025-01-13 17:30:51,146 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:30:51,146 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:30:51,146 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:30:51,147 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:30:51,147 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:30:51,147 - DEBUG - header: date: Mon, 13 Jan 2025 12:00:50 GMT
# 2025-01-13 17:30:51,148 - DEBUG - header: content-length: 206112
# 2025-01-13 17:30:51,148 - DEBUG - header: apikey: Yes
# 2025-01-13 17:30:51,148 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:30:51,148 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=1100&resultsPerPage=100 HTTP/1.1" 200 206112
# 2025-01-13 17:30:51,716 - INFO - Successfully retrieved data for startIndex=1100
# 2025-01-13 17:30:51,719 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:30:57,726 - INFO - Fetching data with startIndex=1200
# 2025-01-13 17:30:57,730 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:30:58,439 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=1200&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:31:08,296 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:31:08,298 - DEBUG - header: content-type: application/json
# 2025-01-13 17:31:08,299 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:31:08,300 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:31:08,300 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:31:08,300 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:31:08,301 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:31:08,301 - DEBUG - header: date: Mon, 13 Jan 2025 12:01:07 GMT
# 2025-01-13 17:31:08,301 - DEBUG - header: content-length: 196593
# 2025-01-13 17:31:08,301 - DEBUG - header: apikey: Yes
# 2025-01-13 17:31:08,302 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:31:08,302 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=1200&resultsPerPage=100 HTTP/1.1" 200 196593
# 2025-01-13 17:31:08,841 - INFO - Successfully retrieved data for startIndex=1200
# 2025-01-13 17:31:08,846 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:31:14,853 - INFO - Fetching data with startIndex=1300
# 2025-01-13 17:31:14,859 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:31:15,586 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=1300&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:31:17,288 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:31:17,290 - DEBUG - header: content-type: application/json
# 2025-01-13 17:31:17,290 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:31:17,291 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:31:17,291 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:31:17,291 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:31:17,292 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:31:17,292 - DEBUG - header: date: Mon, 13 Jan 2025 12:01:16 GMT
# 2025-01-13 17:31:17,292 - DEBUG - header: content-length: 197860
# 2025-01-13 17:31:17,293 - DEBUG - header: apikey: Yes
# 2025-01-13 17:31:17,293 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:31:17,293 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=1300&resultsPerPage=100 HTTP/1.1" 200 197860
# 2025-01-13 17:31:17,844 - INFO - Successfully retrieved data for startIndex=1300
# 2025-01-13 17:31:17,848 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:31:23,849 - INFO - Fetching data with startIndex=1400
# 2025-01-13 17:31:23,852 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:31:24,577 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=1400&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:31:28,159 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:31:28,160 - DEBUG - header: content-type: application/json
# 2025-01-13 17:31:28,161 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:31:28,161 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:31:28,161 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:31:28,161 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:31:28,162 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:31:28,162 - DEBUG - header: date: Mon, 13 Jan 2025 12:01:26 GMT
# 2025-01-13 17:31:28,162 - DEBUG - header: content-length: 175915
# 2025-01-13 17:31:28,162 - DEBUG - header: apikey: Yes
# 2025-01-13 17:31:28,163 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:31:28,163 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=1400&resultsPerPage=100 HTTP/1.1" 200 175915
# 2025-01-13 17:31:28,695 - INFO - Successfully retrieved data for startIndex=1400
# 2025-01-13 17:31:28,698 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:31:34,705 - INFO - Fetching data with startIndex=1500
# 2025-01-13 17:31:34,710 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:31:35,401 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=1500&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:31:45,423 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:31:45,425 - DEBUG - header: content-type: application/json
# 2025-01-13 17:31:45,425 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:31:45,426 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:31:45,426 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:31:45,427 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:31:45,427 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:31:45,428 - DEBUG - header: date: Mon, 13 Jan 2025 12:01:44 GMT
# 2025-01-13 17:31:45,429 - DEBUG - header: content-length: 212553
# 2025-01-13 17:31:45,430 - DEBUG - header: apikey: Yes
# 2025-01-13 17:31:45,431 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:31:45,432 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=1500&resultsPerPage=100 HTTP/1.1" 200 212553
# 2025-01-13 17:31:46,107 - INFO - Successfully retrieved data for startIndex=1500
# 2025-01-13 17:31:46,113 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:31:52,120 - INFO - Fetching data with startIndex=1600
# 2025-01-13 17:31:52,123 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:31:52,821 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=1600&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:31:59,056 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:31:59,058 - DEBUG - header: content-type: application/json
# 2025-01-13 17:31:59,058 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:31:59,059 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:31:59,059 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:31:59,059 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:31:59,059 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:31:59,060 - DEBUG - header: date: Mon, 13 Jan 2025 12:01:58 GMT
# 2025-01-13 17:31:59,060 - DEBUG - header: content-length: 197513
# 2025-01-13 17:31:59,060 - DEBUG - header: apikey: Yes
# 2025-01-13 17:31:59,060 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:31:59,061 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=1600&resultsPerPage=100 HTTP/1.1" 200 197513
# 2025-01-13 17:31:59,604 - INFO - Successfully retrieved data for startIndex=1600
# 2025-01-13 17:31:59,607 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:32:05,613 - INFO - Fetching data with startIndex=1700
# 2025-01-13 17:32:05,616 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:32:06,297 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=1700&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:32:13,130 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:32:13,132 - DEBUG - header: content-type: application/json
# 2025-01-13 17:32:13,132 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:32:13,132 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:32:13,132 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:32:13,133 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:32:13,133 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:32:13,133 - DEBUG - header: date: Mon, 13 Jan 2025 12:02:12 GMT
# 2025-01-13 17:32:13,134 - DEBUG - header: content-length: 210512
# 2025-01-13 17:32:13,134 - DEBUG - header: apikey: Yes
# 2025-01-13 17:32:13,134 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:32:13,135 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=1700&resultsPerPage=100 HTTP/1.1" 200 210512
# 2025-01-13 17:32:13,673 - INFO - Successfully retrieved data for startIndex=1700
# 2025-01-13 17:32:13,676 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:32:19,679 - INFO - Fetching data with startIndex=1800
# 2025-01-13 17:32:19,682 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:32:20,406 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=1800&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:32:27,907 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:32:27,908 - DEBUG - header: content-type: application/json
# 2025-01-13 17:32:27,909 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:32:27,909 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:32:27,909 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:32:27,910 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:32:27,910 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:32:27,910 - DEBUG - header: date: Mon, 13 Jan 2025 12:02:26 GMT
# 2025-01-13 17:32:27,910 - DEBUG - header: content-length: 227632
# 2025-01-13 17:32:27,911 - DEBUG - header: apikey: Yes
# 2025-01-13 17:32:27,911 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:32:27,911 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=1800&resultsPerPage=100 HTTP/1.1" 200 227632
# 2025-01-13 17:32:28,630 - INFO - Successfully retrieved data for startIndex=1800
# 2025-01-13 17:32:28,635 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:32:34,642 - INFO - Fetching data with startIndex=1900
# 2025-01-13 17:32:34,645 - DEBUG - Starting new HTTPS connection (1): services.nvd.nist.gov:443
# 2025-01-13 17:32:35,346 - DEBUG - send: b'GET /rest/json/cves/2.0?startIndex=1900&resultsPerPage=100 HTTP/1.1\r\nHost: services.nvd.nist.gov\r\nUser-Agent: python-requests/2.32.3\r\nAccept-Encoding: gzip, deflate, br\r\nAccept: */*\r\nConnection: keep-alive\r\napiKey: d0f53b52-e8ce-43c6-8e8d-20a6183c9a56\r\n\r\n'
# 2025-01-13 17:32:43,882 - DEBUG - reply: 'HTTP/1.1 200 OK\r\n'
# 2025-01-13 17:32:43,883 - DEBUG - header: content-type: application/json
# 2025-01-13 17:32:43,883 - DEBUG - header: x-frame-options: SAMEORIGIN
# 2025-01-13 17:32:43,884 - DEBUG - header: access-control-allow-origin: *
# 2025-01-13 17:32:43,884 - DEBUG - header: access-control-allow-headers: accept, apiKey, content-type, origin, x-requested-with
# 2025-01-13 17:32:43,884 - DEBUG - header: access-control-allow-methods: GET, HEAD, OPTIONS
# 2025-01-13 17:32:43,884 - DEBUG - header: access-control-allow-credentials: false
# 2025-01-13 17:32:43,885 - DEBUG - header: date: Mon, 13 Jan 2025 12:02:42 GMT
# 2025-01-13 17:32:43,885 - DEBUG - header: content-length: 233425
# 2025-01-13 17:32:43,885 - DEBUG - header: apikey: Yes
# 2025-01-13 17:32:43,885 - DEBUG - header: strict-transport-security: max-age=31536000
# 2025-01-13 17:32:43,886 - DEBUG - https://services.nvd.nist.gov:443 "GET /rest/json/cves/2.0?startIndex=1900&resultsPerPage=100 HTTP/1.1" 200 233425
# 2025-01-13 17:32:44,598 - INFO - Successfully retrieved data for startIndex=1900
# 2025-01-13 17:32:44,601 - INFO - Sleeping for 6 seconds to respect rate limiting.
# 2025-01-13 17:32:50,631 - INFO - Data successfully saved to nvd_cves.csv
